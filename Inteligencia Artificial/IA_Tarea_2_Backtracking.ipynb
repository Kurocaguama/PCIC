# %% [markdown]
# # Tarea 2:
#
# Instrucciones de ejecución:
# 1. Cambiar la dirección de los archivos en el caso del coloreado. Como se corrió de manera local se tiene la dirección de los archivos en mi computadora.
# 2. Para el caso de Minimax hay que clonar el repositorio y mudarse a ese directorio. (Cosa que se hace en el notebook, así que evitar clonar dos veces el repositorio es importante)

# %% [markdown]
# ## Backtracking
#
# La implementación de este algoritmo se ajustará al problema en cuestión, por lo que primero tendremos que representar los problemas de N-Reinas al igual que los de coloreado antes de desarrollar los algoritmos mismos.

# %% [markdown]
# ### N_Reinas

# %%
# Las funciones necesarias para la implementación sobre el problema de la N-Reinas

def valid(tablero, fila, columnas, n):
    """
    Verifica si el estado en observación es un estado aceptable para agregar una reina.
    Es equivalente a una implementación equivalente a Backtracking + Revisión hacia adelante , ya que
    antes de colocar la reina verifica que la posición donde busca colocarla sea la óptima. 

    Está altamente ajustada a la representación del tablero usada. Difícil de extender a una CSP general.
    """
    
    # Verificación por filas    
    for i in range(columnas):
        if tablero[fila][i] == 'R':
            #print("Fila")
            return False

    # Verificación por diagonal superior
    for i, j in zip(range(fila, -1, -1), range(columnas, -1, -1)):
        if tablero[i][j] == 'R':
            #print("Diag Sup")
            return False

    # Verificación por diagonal inferior
    for i, j in zip(range(fila, n, 1), range(columnas, -1, -1)):
        if tablero[i][j] == 'R':
            #print("Diag Inf")
            return False
            
    return True


#Función principal
def n_reinas(n):
    """
    El tablero se representará como un arreglo de n entradas donde cada entrada es un arreglo de n entradas. 
    Para denotar una casilla vacía se usará "-", mientras que para denotar una reina se usará "R".
    Esta función agrega reinas una por una cuidando las restricciones. Itera sobre columnas.
    Verificar que no sea problemática la nueva reina se hace en la función previa valid(tablero, fila, columnas, n)
    """
    
    tablero = [['-' for i in range(n)] for i in range(n)]
    result = []

    def backtrack(tablero, columnas):
        if columnas == n:
            result.append([', '.join(fila) for fila in tablero])
            return

        for i in range(n):
            if valid(tablero, i, columnas, n):
                tablero[i][columnas] = 'R'
                backtrack(tablero, columnas + 1)
                tablero[i][columnas] = '-'

    backtrack(tablero, 0)
    return result

# Despliegue de resultados
def full_n_reinas(n):
    """
    Solo ejecuta las funciones previas con una n definida por el usuario.
    """
    aux = n_reinas(n)
    print(f"Cantidad de reinas: {n}.")
    print(f"Cantidad de soluciones encontradas: {len(aux)}.")
    print("Primera solución encontrada:")
    for i in aux[0]:
        print(i)

# %%
# %%time
# Ejemplos
full_n_reinas(12)
full_n_reinas(8)

# Para n=100 no logré que acabara. Corra esta variable bajo su propio riesgo.
#full_n_reinas(100)
# Out:
# Cantidad de reinas: 12.
# Cantidad de soluciones encontradas: 14200.
# Primera solución encontrada:
# R, -, -, -, -, -, -, -, -, -, -, -
# -, -, -, -, -, -, -, -, R, -, -, -
# -, R, -, -, -, -, -, -, -, -, -, -
# -, -, -, -, -, -, -, -, -, -, -, R
# -, -, R, -, -, -, -, -, -, -, -, -
# -, -, -, -, -, -, R, -, -, -, -, -
# -, -, -, -, -, -, -, -, -, R, -, -
# -, -, -, R, -, -, -, -, -, -, -, -
# -, -, -, -, -, -, -, -, -, -, R, -
# -, -, -, -, R, -, -, -, -, -, -, -
# -, -, -, -, -, -, -, R, -, -, -, -
# -, -, -, -, -, R, -, -, -, -, -, -
# Cantidad de reinas: 8.
# Cantidad de soluciones encontradas: 92.
# Primera solución encontrada:
# R, -, -, -, -, -, -, -
# -, -, -, -, -, -, R, -
# -, -, -, -, R, -, -, -
# -, -, -, -, -, -, -, R
# -, R, -, -, -, -, -, -
# -, -, -, R, -, -, -, -
# -, -, -, -, -, R, -, -
# -, -, R, -, -, -, -, -
# CPU times: total: 6.41 s
# Wall time: 6.42 s

# %% [markdown]
# ### Coloreado

# %%
import networkx as nx #Para facilitar la representación usando grafos.
import time

# Función de procesamiento de texto 
def leer_txt(name_txt):
    """
    Abre y lee el archivo en cuestión.
    Se pasa a una gráfica de nx.Graph() para evitar tener que hacer una implementación particular dependiente del problema.
    (Esta representación es ideal en caso de que se busque implementar para CSP generalizados).
    """
    with open(name_txt, 'r') as file:
        lines = file.readlines()

    n_vertex, n_edge = map(int, lines[0].strip().split())
    grafo = nx.Graph()

    for linea in lines[1:]:
        a, b = map(int, linea.strip().split())
        grafo.add_edge(a, b)

    return grafo

#Función de coloreado
def backtracking_coloreado(grafo):
    """
    Dado que estamos trabajando con una gráfica podemos revisar sus vecinos de una manera más accesible.
    Esta función revisa vecinos, verifica condiciones, y colorea. Es backtracking pero aplicada a este
    problema y a estas variables.
    Dentro de esta función se tiene la función color_posible() que verifica la validez del color sobre vértice.
    """
    coloreado = {}
    order_vertex = sorted(grafo.nodes(), key=lambda x: -len(list(grafo.neighbors(x))))

    def color_posible(vertex, color):
        """
        Verifica que un vértice se pueda pintar de cierto color.
        """
        for next in grafo.neighbors(vertex):
            if coloreado.get(next) == color:
                return False
        return True

    for vertex in order_vertex:
        for color in range(len(order_vertex)):
            if color_posible(vertex, color):
                coloreado[vertex] = color
                break

    return coloreado

#Función mostrar grafo coloreado
def color_graph(name_txt):
    """
    Implementación puntual del algoritmo.
    Se presenta una solución encontrada.
    """
    grafo = leer_txt(name_txt)
    resultado = backtracking_coloreado(grafo)

    if resultado:
        num_colores = max(resultado.values()) + 1
        print("Se encontró la siguiente solución:")
        print(f"Número de colores: {num_colores}")
        for vertex, color in resultado.items():
            print(f"Color: {color}, vértice {vertex}")
    else:
        print("Solución no encontrada")

# %%
# %%time

#Implementación con los datasets necesarios.
#Corre en un tiempo bastante razonable así que no hay problema en ejecutar toda la celda.

nodos50 = r"C:\Users\FLopezP\Desktop\PCIC\IA\Prácticas\gc_50_7 (1)"
color_graph(nodos50)

print("-------------------------------------")
nodos1000 = r"C:\Users\FLopezP\Desktop\PCIC\IA\Prácticas\gc_1000_9 (1)"
color_graph(nodos1000)
# Out:
# Se encontró la siguiente solución:
# Número de colores: 18
# Color: 0, vértice 11
# Color: 1, vértice 31
# Color: 2, vértice 38
# Color: 3, vértice 40
# Color: 4, vértice 36
# Color: 4, vértice 3
# Color: 1, vértice 10
# Color: 3, vértice 33
# Color: 5, vértice 35
# Color: 6, vértice 18
# Color: 2, vértice 48
# Color: 6, vértice 0
# Color: 7, vértice 4
# Color: 7, vértice 22
# Color: 8, vértice 23
# Color: 9, vértice 32
# Color: 9, vértice 43
# Color: 8, vértice 19
# Color: 8, vértice 21
# Color: 10, vértice 27
# Color: 1, vértice 34
# Color: 10, vértice 37
# Color: 5, vértice 39
# Color: 11, vértice 47
# Color: 12, vértice 28
# Color: 0, vértice 5
# Color: 11, vértice 6
# Color: 13, vértice 9
# Color: 5, vértice 12
# Color: 11, vértice 13
# Color: 14, vértice 14
# Color: 15, vértice 17
# Color: 2, vértice 29
# Color: 3, vértice 30
# Color: 12, vértice 49
# Color: 11, vértice 1
# Color: 10, vértice 24
# Color: 13, vértice 25
# Color: 14, vértice 41
# Color: 7, vértice 2
# Color: 16, vértice 8
# Color: 15, vértice 15
# Color: 0, vértice 26
# Color: 0, vértice 7
# Color: 13, vértice 42
# Color: 14, vértice 46
# Color: 12, vértice 45
# Color: 4, vértice 16
# Color: 16, vértice 20
# Color: 17, vértice 44
# -------------------------------------
# Se encontró la siguiente solución:
# Número de colores: 314
# Color: 0, vértice 652
# Color: 1, vértice 881
# Color: 2, vértice 439
# Color: 1, vértice 604
# Color: 3, vértice 294
# Color: 4, vértice 592
# Color: 5, vértice 171
# Color: 6, vértice 433
# Color: 7, vértice 497
# Color: 8, vértice 828
# Color: 9, vértice 904
# Color: 8, vértice 532
# Color: 2, vértice 8
# Color: 10, vértice 293
# Color: 11, vértice 371
# Color: 0, vértice 703
# Color: 12, vértice 802
# Color: 3, vértice 877
# Color: 13, vértice 92
# Color: 14, vértice 145
# Color: 10, vértice 178
# Color: 15, vértice 240
# Color: 7, vértice 243
# Color: 5, vértice 518
# Color: 16, vértice 596
# Color: 6, vértice 669
# Color: 17, vértice 720
# Color: 18, vértice 770
# Color: 19, vértice 833
# Color: 11, vértice 479
# Color: 20, vértice 665
# Color: 9, vértice 690
# Color: 21, vértice 883
# Color: 18, vértice 943
# Color: 0, vértice 115
# Color: 4, vértice 52
# Color: 22, vértice 143
# Color: 23, vértice 307
# Color: 15, vértice 321
# Color: 12, vértice 325
# Color: 22, vértice 375
# Color: 24, vértice 462
# Color: 25, vértice 506
# Color: 26, vértice 777
# Color: 21, vértice 782
# Color: 14, vértice 277
# Color: 27, vértice 176
# Color: 28, vértice 215
# Color: 29, vértice 525
# Color: 26, vértice 527
# Color: 27, vértice 607
# Color: 23, vértice 688
# Color: 30, vértice 740
# Color: 31, vértice 811
# Color: 30, vértice 410
# Color: 28, vértice 66
# Color: 32, vértice 83
# Color: 17, vértice 220
# Color: 29, vértice 347
# Color: 13, vértice 405
# Color: 32, vértice 521
# Color: 33, vértice 580
# Color: 34, vértice 717
# Color: 35, vértice 725
# Color: 29, vértice 894
# Color: 16, vértice 987
# Color: 36, vértice 999
# Color: 37, vértice 636
# Color: 38, vértice 745
# Color: 38, vértice 11
# Color: 33, vértice 80
# Color: 20, vértice 97
# Color: 39, vértice 181
# Color: 19, vértice 268
# Color: 36, vértice 423
# Color: 40, vértice 456
# Color: 41, vértice 574
# Color: 42, vértice 629
# Color: 31, vértice 685
# Color: 43, vértice 963
# Color: 35, vértice 22
# Color: 22, vértice 95
# Color: 44, vértice 101
# Color: 45, vértice 190
# Color: 13, vértice 269
# Color: 28, vértice 329
# Color: 11, vértice 345
# Color: 45, vértice 374
# Color: 46, vértice 414
# Color: 47, vértice 585
# Color: 43, vértice 586
# Color: 42, vértice 617
# Color: 48, vértice 650
# Color: 49, vértice 753
# Color: 47, vértice 787
# Color: 50, vértice 821
# Color: 39, vértice 848
# Color: 49, vértice 20
# Color: 37, vértice 806
# Color: 7, vértice 25
# Color: 51, vértice 72
# Color: 52, vértice 116
# Color: 51, vértice 186
# Color: 53, vértice 206
# Color: 25, vértice 255
# Color: 54, vértice 257
# Color: 41, vértice 403
# Color: 6, vértice 513
# Color: 46, vértice 628
# Color: 52, vértice 715
# Color: 9, vértice 718
# Color: 55, vértice 737
# Color: 50, vértice 901
# Color: 56, vértice 885
# Color: 5, vértice 18
# Color: 34, vértice 140
# Color: 55, vértice 207
# Color: 38, vértice 219
# Color: 57, vértice 235
# Color: 53, vértice 288
# Color: 58, vértice 317
# Color: 59, vértice 393
# Color: 23, vértice 470
# Color: 60, vértice 548
# Color: 48, vértice 630
# Color: 61, vértice 708
# Color: 62, vértice 771
# Color: 63, vértice 772
# Color: 64, vértice 781
# Color: 54, vértice 790
# Color: 64, vértice 843
# Color: 65, vértice 984
# Color: 57, vértice 988
# Color: 24, vértice 990
# Color: 65, vértice 991
# Color: 66, vértice 54
# Color: 67, vértice 193
# Color: 60, vértice 956
# Color: 44, vértice 982
# Color: 51, vértice 71
# Color: 68, vértice 76
# Color: 24, vértice 105
# Color: 58, vértice 113
# Color: 67, vértice 121
# Color: 68, vértice 225
# Color: 32, vértice 292
# Color: 69, vértice 368
# Color: 56, vértice 407
# Color: 62, vértice 429
# Color: 40, vértice 473
# Color: 66, vértice 587
# Color: 59, vértice 667
# Color: 70, vértice 706
# Color: 71, vértice 761
# Color: 44, vértice 773
# Color: 72, vértice 860
# Color: 71, vértice 961
# Color: 73, vértice 971
# Color: 73, vértice 338
# Color: 37, vértice 0
# Color: 74, vértice 34
# Color: 74, vértice 88
# Color: 27, vértice 98
# Color: 31, vértice 198
# Color: 34, vértice 241
# Color: 69, vértice 331
# Color: 75, vértice 435
# Color: 26, vértice 449
# Color: 76, vértice 474
# Color: 72, vértice 489
# Color: 61, vértice 503
# Color: 49, vértice 552
# Color: 77, vértice 684
# Color: 78, vértice 696
# Color: 11, vértice 729
# Color: 79, vértice 791
# Color: 80, vértice 801
# Color: 40, vértice 824
# Color: 65, vértice 857
# Color: 75, vértice 887
# Color: 78, vértice 903
# Color: 81, vértice 928
# Color: 82, vértice 985
# Color: 83, vértice 638
# Color: 82, vértice 890
# Color: 76, vértice 914
# Color: 84, vértice 937
# Color: 85, vértice 980
# Color: 86, vértice 734
# Color: 43, vértice 42
# Color: 87, vértice 53
# Color: 79, vértice 90
# Color: 77, vértice 91
# Color: 88, vértice 131
# Color: 85, vértice 156
# Color: 12, vértice 169
# Color: 89, vértice 188
# Color: 70, vértice 203
# Color: 80, vértice 204
# Color: 61, vértice 217
# Color: 81, vértice 253
# Color: 87, vértice 263
# Color: 89, vértice 301
# Color: 90, vértice 357
# Color: 91, vértice 372
# Color: 63, vértice 388
# Color: 64, vértice 404
# Color: 86, vértice 467
# Color: 92, vértice 469
# Color: 91, vértice 477
# Color: 93, vértice 546
# Color: 94, vértice 619
# Color: 21, vértice 670
# Color: 68, vértice 874
# Color: 36, vértice 936
# Color: 88, vértice 955
# Color: 15, vértice 48
# Color: 95, vértice 391
# Color: 96, vértice 424
# Color: 4, vértice 426
# Color: 90, vértice 693
# Color: 94, vértice 39
# Color: 97, vértice 47
# Color: 98, vértice 86
# Color: 96, vértice 162
# Color: 99, vértice 232
# Color: 84, vértice 234
# Color: 100, vértice 237
# Color: 83, vértice 254
# Color: 101, vértice 394
# Color: 80, vértice 438
# Color: 84, vértice 464
# Color: 8, vértice 466
# Color: 99, vértice 516
# Color: 102, vértice 588
# Color: 98, vértice 654
# Color: 103, vértice 660
# Color: 93, vértice 750
# Color: 104, vértice 763
# Color: 103, vértice 798
# Color: 93, vértice 819
# Color: 91, vértice 820
# Color: 78, vértice 866
# Color: 46, vértice 909
# Color: 105, vértice 746
# Color: 105, vértice 24
# Color: 18, vértice 73
# Color: 56, vértice 153
# Color: 16, vértice 165
# Color: 106, vértice 180
# Color: 107, vértice 205
# Color: 108, vértice 214
# Color: 14, vértice 251
# Color: 109, vértice 275
# Color: 92, vértice 276
# Color: 109, vértice 286
# Color: 95, vértice 328
# Color: 110, vértice 336
# Color: 42, vértice 340
# Color: 100, vértice 366
# Color: 104, vértice 392
# Color: 104, vértice 443
# Color: 53, vértice 446
# Color: 111, vértice 478
# Color: 10, vértice 485
# Color: 101, vértice 499
# Color: 97, vértice 534
# Color: 107, vértice 560
# Color: 70, vértice 563
# Color: 99, vértice 564
# Color: 112, vértice 632
# Color: 113, vértice 698
# Color: 112, vértice 754
# Color: 48, vértice 757
# Color: 114, vértice 779
# Color: 106, vértice 783
# Color: 69, vértice 805
# Color: 115, vértice 809
# Color: 116, vértice 818
# Color: 102, vértice 898
# Color: 117, vértice 974
# Color: 118, vértice 977
# Color: 108, vértice 70
# Color: 115, vértice 593
# Color: 107, vértice 9
# Color: 33, vértice 10
# Color: 111, vértice 31
# Color: 110, vértice 43
# Color: 119, vértice 81
# Color: 35, vértice 129
# Color: 116, vértice 144
# Color: 54, vértice 226
# Color: 120, vértice 281
# Color: 39, vértice 309
# Color: 121, vértice 342
# Color: 95, vértice 398
# Color: 45, vértice 452
# Color: 122, vértice 465
# Color: 60, vértice 481
# Color: 113, vértice 492
# Color: 123, vértice 526
# Color: 1, vértice 537
# Color: 81, vértice 572
# Color: 123, vértice 584
# Color: 124, vértice 594
# Color: 2, vértice 605
# Color: 119, vértice 611
# Color: 55, vértice 668
# Color: 117, vértice 711
# Color: 125, vértice 814
# Color: 97, vértice 845
# Color: 125, vértice 873
# Color: 126, vértice 896
# Color: 127, vértice 917
# Color: 73, vértice 932
# Color: 46, vértice 175
# Color: 17, vértice 367
# Color: 114, vértice 966
# Color: 102, vértice 13
# Color: 96, vértice 51
# Color: 127, vértice 74
# Color: 118, vértice 151
# Color: 121, vértice 154
# Color: 126, vértice 155
# Color: 128, vértice 192
# Color: 25, vértice 221
# Color: 16, vértice 259
# Color: 71, vértice 283
# Color: 59, vértice 297
# Color: 74, vértice 304
# Color: 120, vértice 318
# Color: 129, vértice 330
# Color: 122, vértice 401
# Color: 77, vértice 420
# Color: 130, vértice 468
# Color: 131, vértice 487
# Color: 132, vértice 538
# Color: 133, vértice 553
# Color: 134, vértice 566
# Color: 44, vértice 568
# Color: 135, vértice 569
# Color: 130, vértice 625
# Color: 135, vértice 631
# Color: 136, vértice 634
# Color: 136, vértice 683
# Color: 131, vértice 778
# Color: 120, vértice 780
# Color: 89, vértice 846
# Color: 79, vértice 884
# Color: 66, vértice 922
# Color: 137, vértice 931
# Color: 50, vértice 933
# Color: 129, vértice 934
# Color: 138, vértice 950
# Color: 139, vértice 989
# Color: 86, vértice 741
# Color: 132, vértice 895
# Color: 140, vértice 785
# Color: 139, vértice 6
# Color: 121, vértice 29
# Color: 135, vértice 30
# Color: 141, vértice 41
# Color: 142, vértice 56
# Color: 114, vértice 107
# Color: 143, vértice 111
# Color: 92, vértice 124
# Color: 144, vértice 135
# Color: 145, vértice 157
# Color: 52, vértice 167
# Color: 63, vértice 224
# Color: 124, vértice 233
# Color: 141, vértice 239
# Color: 41, vértice 273
# Color: 143, vértice 282
# Color: 2, vértice 313
# Color: 133, vértice 365
# Color: 20, vértice 369
# Color: 138, vértice 387
# Color: 146, vértice 453
# Color: 115, vértice 476
# Color: 146, vértice 488
# Color: 147, vértice 530
# Color: 75, vértice 549
# Color: 85, vértice 599
# Color: 142, vértice 606
# Color: 148, vértice 640
# Color: 147, vértice 651
# Color: 140, vértice 678
# Color: 87, vértice 680
# Color: 149, vértice 691
# Color: 149, vértice 695
# Color: 127, vértice 721
# Color: 140, vértice 733
# Color: 150, vértice 736
# Color: 151, vértice 742
# Color: 150, vértice 807
# Color: 152, vértice 875
# Color: 144, vértice 902
# Color: 128, vértice 921
# Color: 124, vértice 948
# Color: 134, vértice 952
# Color: 153, vértice 972
# Color: 154, vértice 248
# Color: 153, vértice 954
# Color: 152, vértice 2
# Color: 145, vértice 170
# Color: 154, vértice 183
# Color: 152, vértice 191
# Color: 155, vértice 244
# Color: 137, vértice 280
# Color: 103, vértice 324
# Color: 156, vértice 327
# Color: 113, vértice 356
# Color: 157, vértice 364
# Color: 88, vértice 383
# Color: 151, vértice 402
# Color: 158, vértice 419
# Color: 106, vértice 451
# Color: 83, vértice 502
# Color: 159, vértice 602
# Color: 159, vértice 603
# Color: 160, vértice 610
# Color: 161, vértice 622
# Color: 158, vértice 645
# Color: 72, vértice 653
# Color: 162, vértice 657
# Color: 157, vértice 675
# Color: 147, vértice 712
# Color: 143, vértice 714
# Color: 149, vértice 719
# Color: 62, vértice 722
# Color: 122, vértice 799
# Color: 153, vértice 822
# Color: 144, vértice 823
# Color: 53, vértice 854
# Color: 148, vértice 879
# Color: 156, vértice 926
# Color: 163, vértice 927
# Color: 136, vértice 960
# Color: 14, vértice 978
# Color: 164, vértice 998
# Color: 110, vértice 21
# Color: 105, vértice 26
# Color: 131, vértice 50
# Color: 165, vértice 77
# Color: 58, vértice 152
# Color: 154, vértice 216
# Color: 166, vértice 223
# Color: 3, vértice 250
# Color: 160, vértice 262
# Color: 166, vértice 353
# Color: 165, vértice 390
# Color: 165, vértice 396
# Color: 167, vértice 415
# Color: 168, vértice 486
# Color: 161, vértice 494
# Color: 155, vértice 495
# Color: 162, vértice 529
# Color: 148, vértice 614
# Color: 169, vértice 641
# Color: 170, vértice 663
# Color: 88, vértice 700
# Color: 146, vértice 738
# Color: 128, vértice 758
# Color: 171, vértice 765
# Color: 19, vértice 789
# Color: 116, vértice 838
# Color: 169, vértice 844
# Color: 171, vértice 891
# Color: 172, vértice 953
# Color: 168, vértice 979
# Color: 163, vértice 986
# Color: 173, vértice 994
# Color: 174, vértice 459
# Color: 163, vértice 702
# Color: 158, vértice 3
# Color: 167, vértice 15
# Color: 175, vértice 106
# Color: 129, vértice 123
# Color: 174, vértice 136
# Color: 145, vértice 174
# Color: 130, vértice 185
# Color: 94, vértice 194
# Color: 164, vértice 247
# Color: 82, vértice 298
# Color: 135, vértice 302
# Color: 176, vértice 362
# Color: 108, vértice 363
# Color: 172, vértice 384
# Color: 132, vértice 445
# Color: 177, vértice 496
# Color: 176, vértice 508
# Color: 178, vértice 511
# Color: 179, vértice 519
# Color: 134, vértice 523
# Color: 170, vértice 531
# Color: 180, vértice 581
# Color: 180, vértice 647
# Color: 181, vértice 697
# Color: 164, vértice 732
# Color: 182, vértice 739
# Color: 174, vértice 756
# Color: 178, vértice 786
# Color: 183, vértice 851
# Color: 177, vértice 858
# Color: 184, vértice 863
# Color: 179, vértice 868
# Color: 155, vértice 918
# Color: 173, vértice 925
# Color: 175, vértice 981
# Color: 185, vértice 78
# Color: 85, vértice 315
# Color: 183, vértice 655
# Color: 182, vértice 112
# Color: 123, vértice 197
# Color: 186, vértice 236
# Color: 185, vértice 242
# Color: 187, vértice 249
# Color: 139, vértice 265
# Color: 188, vértice 278
# Color: 160, vértice 314
# Color: 184, vértice 379
# Color: 189, vértice 380
# Color: 190, vértice 389
# Color: 169, vértice 413
# Color: 191, vértice 437
# Color: 171, vértice 448
# Color: 192, vértice 458
# Color: 181, vértice 558
# Color: 182, vértice 613
# Color: 193, vértice 677
# Color: 191, vértice 682
# Color: 167, vértice 694
# Color: 15, vértice 731
# Color: 194, vértice 797
# Color: 180, vértice 813
# Color: 126, vértice 837
# Color: 188, vértice 865
# Color: 195, vértice 913
# Color: 194, vértice 945
# Color: 189, vértice 967
# Color: 186, vértice 557
# Color: 190, vértice 55
# Color: 196, vértice 79
# Color: 100, vértice 84
# Color: 176, vértice 126
# Color: 192, vértice 130
# Color: 150, vértice 137
# Color: 94, vértice 150
# Color: 50, vértice 166
# Color: 197, vértice 195
# Color: 188, vértice 199
# Color: 30, vértice 231
# Color: 58, vértice 305
# Color: 175, vértice 344
# Color: 195, vértice 360
# Color: 113, vértice 411
# Color: 198, vértice 418
# Color: 155, vértice 475
# Color: 197, vértice 482
# Color: 111, vértice 491
# Color: 187, vértice 520
# Color: 199, vértice 541
# Color: 200, vértice 576
# Color: 182, vértice 597
# Color: 196, vértice 612
# Color: 201, vértice 639
# Color: 193, vértice 642
# Color: 189, vértice 704
# Color: 201, vértice 709
# Color: 133, vértice 723
# Color: 202, vértice 724
# Color: 203, vértice 815
# Color: 198, vértice 862
# Color: 157, vértice 892
# Color: 38, vértice 929
# Color: 175, vértice 938
# Color: 151, vértice 939
# Color: 141, vértice 944
# Color: 158, vértice 958
# Color: 203, vértice 973
# Color: 199, vértice 976
# Color: 204, vértice 997
# Color: 90, vértice 662
# Color: 204, vértice 840
# Color: 205, vértice 17
# Color: 205, vértice 38
# Color: 198, vértice 46
# Color: 159, vértice 67
# Color: 161, vértice 100
# Color: 67, vértice 103
# Color: 206, vértice 122
# Color: 207, vértice 146
# Color: 208, vértice 148
# Color: 209, vértice 229
# Color: 200, vértice 230
# Color: 209, vértice 245
# Color: 190, vértice 279
# Color: 210, vértice 326
# Color: 211, vértice 334
# Color: 138, vértice 376
# Color: 202, vértice 377
# Color: 212, vértice 428
# Color: 47, vértice 444
# Color: 213, vértice 457
# Color: 206, vértice 514
# Color: 207, vértice 562
# Color: 211, vértice 579
# Color: 51, vértice 637
# Color: 193, vértice 676
# Color: 214, vértice 707
# Color: 212, vértice 808
# Color: 181, vértice 825
# Color: 215, vértice 835
# Color: 95, vértice 852
# Color: 213, vértice 861
# Color: 214, vértice 886
# Color: 216, vértice 888
# Color: 210, vértice 900
# Color: 217, vértice 957
# Color: 204, vértice 975
# Color: 218, vértice 600
# Color: 218, vértice 61
# Color: 219, vértice 87
# Color: 220, vértice 109
# Color: 196, vértice 138
# Color: 173, vértice 159
# Color: 200, vértice 189
# Color: 220, vértice 271
# Color: 221, vértice 295
# Color: 86, vértice 303
# Color: 156, vértice 310
# Color: 222, vértice 359
# Color: 223, vértice 385
# Color: 112, vértice 409
# Color: 212, vértice 417
# Color: 195, vértice 472
# Color: 221, vértice 483
# Color: 129, vértice 512
# Color: 204, vértice 571
# Color: 224, vértice 726
# Color: 119, vértice 752
# Color: 187, vértice 755
# Color: 219, vértice 759
# Color: 225, vértice 767
# Color: 226, vértice 812
# Color: 98, vértice 817
# Color: 137, vértice 880
# Color: 225, vértice 915
# Color: 206, vértice 942
# Color: 179, vértice 962
# Color: 214, vértice 995
# Color: 216, vértice 408
# Color: 199, vértice 849
# Color: 208, vértice 23
# Color: 109, vértice 45
# Color: 192, vértice 64
# Color: 227, vértice 102
# Color: 228, vértice 163
# Color: 212, vértice 182
# Color: 217, vértice 201
# Color: 226, vértice 202
# Color: 165, vértice 227
# Color: 224, vértice 228
# Color: 229, vértice 311
# Color: 216, vértice 333
# Color: 216, vértice 348
# Color: 228, vértice 349
# Color: 229, vértice 358
# Color: 142, vértice 361
# Color: 68, vértice 370
# Color: 140, vértice 501
# Color: 230, vértice 522
# Color: 231, vértice 533
# Color: 147, vértice 542
# Color: 232, vértice 577
# Color: 231, vértice 582
# Color: 194, vértice 618
# Color: 223, vértice 748
# Color: 233, vértice 769
# Color: 234, vértice 876
# Color: 235, vértice 905
# Color: 235, vértice 907
# Color: 232, vértice 940
# Color: 236, vértice 941
# Color: 222, vértice 965
# Color: 227, vértice 500
# Color: 234, vértice 505
# Color: 237, vértice 565
# Color: 230, vértice 627
# Color: 238, vértice 826
# Color: 239, vértice 19
# Color: 238, vértice 58
# Color: 237, vértice 60
# Color: 240, vértice 89
# Color: 239, vértice 133
# Color: 117, vértice 134
# Color: 215, vértice 258
# Color: 211, vértice 267
# Color: 47, vértice 272
# Color: 241, vértice 284
# Color: 242, vértice 343
# Color: 243, vértice 412
# Color: 241, vértice 450
# Color: 233, vértice 463
# Color: 217, vértice 666
# Color: 244, vértice 687
# Color: 124, vértice 751
# Color: 245, vértice 775
# Color: 172, vértice 800
# Color: 230, vértice 827
# Color: 242, vértice 834
# Color: 246, vértice 841
# Color: 168, vértice 859
# Color: 183, vértice 878
# Color: 222, vértice 911
# Color: 236, vértice 923
# Color: 203, vértice 951
# Color: 246, vértice 993
# Color: 178, vértice 4
# Color: 247, vértice 187
# Color: 248, vértice 266
# Color: 118, vértice 427
# Color: 185, vértice 490
# Color: 162, vértice 635
# Color: 243, vértice 649
# Color: 249, vértice 842
# Color: 209, vértice 853
# Color: 232, vértice 289
# Color: 244, vértice 147
# Color: 248, vértice 158
# Color: 249, vértice 196
# Color: 101, vértice 200
# Color: 229, vértice 209
# Color: 76, vértice 210
# Color: 76, vértice 211
# Color: 225, vértice 260
# Color: 250, vértice 308
# Color: 171, vértice 382
# Color: 251, vértice 421
# Color: 247, vértice 498
# Color: 251, vértice 544
# Color: 202, vértice 595
# Color: 170, vértice 659
# Color: 240, vértice 673
# Color: 252, vértice 749
# Color: 253, vértice 768
# Color: 254, vértice 776
# Color: 222, vértice 847
# Color: 221, vértice 870
# Color: 247, vértice 930
# Color: 206, vértice 983
# Color: 254, vértice 436
# Color: 255, vértice 567
# Color: 66, vértice 65
# Color: 138, vértice 96
# Color: 208, vértice 104
# Color: 250, vértice 117
# Color: 256, vértice 160
# Color: 187, vértice 264
# Color: 253, vértice 323
# Color: 207, vértice 332
# Color: 257, vértice 335
# Color: 100, vértice 346
# Color: 258, vértice 351
# Color: 215, vértice 432
# Color: 136, vértice 461
# Color: 20, vértice 504
# Color: 253, vértice 509
# Color: 236, vértice 510
# Color: 245, vértice 517
# Color: 220, vértice 620
# Color: 235, vértice 648
# Color: 177, vértice 661
# Color: 259, vértice 674
# Color: 260, vértice 689
# Color: 50, vértice 692
# Color: 228, vértice 710
# Color: 256, vértice 744
# Color: 191, vértice 766
# Color: 258, vértice 793
# Color: 261, vértice 830
# Color: 201, vértice 831
# Color: 262, vértice 920
# Color: 259, vértice 959
# Color: 193, vértice 139
# Color: 252, vértice 287
# Color: 219, vértice 539
# Color: 227, vértice 626
# Color: 226, vértice 996
# Color: 248, vértice 16
# Color: 238, vértice 32
# Color: 262, vértice 36
# Color: 252, vértice 125
# Color: 258, vértice 132
# Color: 260, vértice 172
# Color: 263, vértice 208
# Color: 264, vértice 246
# Color: 265, vértice 274
# Color: 250, vértice 484
# Color: 263, vértice 540
# Color: 266, vértice 550
# Color: 224, vértice 570
# Color: 244, vértice 646
# Color: 265, vértice 699
# Color: 242, vértice 728
# Color: 267, vértice 816
# Color: 218, vértice 850
# Color: 264, vértice 856
# Color: 257, vértice 882
# Color: 268, vértice 889
# Color: 269, vértice 908
# Color: 266, vértice 1
# Color: 270, vértice 5
# Color: 231, vértice 28
# Color: 269, vértice 35
# Color: 261, vértice 85
# Color: 271, vértice 94
# Color: 240, vértice 164
# Color: 185, vértice 173
# Color: 114, vértice 222
# Color: 255, vértice 296
# Color: 272, vértice 299
# Color: 221, vértice 339
# Color: 273, vértice 341
# Color: 241, vértice 352
# Color: 272, vértice 373
# Color: 274, vértice 430
# Color: 275, vértice 543
# Color: 276, vértice 832
# Color: 243, vértice 839
# Color: 81, vértice 864
# Color: 249, vértice 910
# Color: 268, vértice 916
# Color: 248, vértice 947
# Color: 186, vértice 142
# Color: 210, vértice 624
# Color: 92, vértice 743
# Color: 269, vértice 110
# Color: 270, vértice 118
# Color: 265, vértice 177
# Color: 203, vértice 238
# Color: 245, vértice 291
# Color: 271, vértice 306
# Color: 205, vértice 322
# Color: 249, vértice 400
# Color: 87, vértice 447
# Color: 233, vértice 507
# Color: 19, vértice 545
# Color: 277, vértice 556
# Color: 278, vértice 810
# Color: 223, vértice 970
# Color: 276, vértice 49
# Color: 267, vértice 573
# Color: 273, vértice 261
# Color: 228, vértice 312
# Color: 22, vértice 337
# Color: 255, vértice 460
# Color: 263, vértice 559
# Color: 274, vértice 679
# Color: 45, vértice 730
# Color: 279, vértice 795
# Color: 276, vértice 906
# Color: 280, vértice 924
# Color: 23, vértice 946
# Color: 278, vértice 969
# Color: 279, vértice 760
# Color: 281, vértice 27
# Color: 71, vértice 37
# Color: 264, vértice 108
# Color: 282, vértice 149
# Color: 69, vértice 285
# Color: 281, vértice 381
# Color: 279, vértice 434
# Color: 283, vértice 515
# Color: 284, vértice 551
# Color: 257, vértice 555
# Color: 275, vértice 561
# Color: 213, vértice 583
# Color: 12, vértice 672
# Color: 277, vértice 747
# Color: 241, vértice 762
# Color: 239, vértice 855
# Color: 283, vértice 893
# Color: 246, vértice 992
# Color: 234, vértice 716
# Color: 243, vértice 57
# Color: 198, vértice 59
# Color: 166, vértice 63
# Color: 282, vértice 93
# Color: 205, vértice 320
# Color: 280, vértice 355
# Color: 171, vértice 633
# Color: 261, vértice 644
# Color: 284, vértice 664
# Color: 262, vértice 671
# Color: 285, vértice 794
# Color: 48, vértice 212
# Color: 286, vértice 290
# Color: 286, vértice 7
# Color: 287, vértice 44
# Color: 275, vértice 68
# Color: 288, vértice 119
# Color: 285, vértice 141
# Color: 287, vértice 218
# Color: 184, vértice 354
# Color: 148, vértice 455
# Color: 105, vértice 493
# Color: 289, vértice 578
# Color: 290, vértice 601
# Color: 288, vértice 656
# Color: 274, vértice 784
# Color: 259, vértice 899
# Color: 291, vértice 912
# Color: 254, vértice 949
# Color: 289, vértice 99
# Color: 237, vértice 792
# Color: 292, vértice 69
# Color: 293, vértice 252
# Color: 260, vértice 270
# Color: 294, vértice 378
# Color: 271, vértice 397
# Color: 294, vértice 416
# Color: 295, vértice 454
# Color: 273, vértice 480
# Color: 296, vértice 535
# Color: 288, vértice 536
# Color: 293, vértice 547
# Color: 291, vértice 554
# Color: 290, vértice 643
# Color: 295, vértice 686
# Color: 297, vértice 701
# Color: 298, vértice 735
# Color: 292, vértice 872
# Color: 299, vértice 964
# Color: 287, vértice 82
# Color: 197, vértice 431
# Color: 299, vértice 386
# Color: 202, vértice 395
# Color: 300, vértice 399
# Color: 298, vértice 598
# Color: 296, vértice 608
# Color: 301, vértice 615
# Color: 176, vértice 713
# Color: 154, vértice 764
# Color: 302, vértice 968
# Color: 159, vértice 422
# Color: 246, vértice 179
# Color: 103, vértice 184
# Color: 134, vértice 256
# Color: 300, vértice 589
# Color: 253, vértice 591
# Color: 282, vértice 774
# Color: 54, vértice 788
# Color: 300, vértice 869
# Color: 289, vértice 897
# Color: 302, vértice 40
# Color: 49, vértice 621
# Color: 303, vértice 705
# Color: 304, vértice 12
# Color: 256, vértice 114
# Color: 277, vértice 120
# Color: 303, vértice 161
# Color: 201, vértice 441
# Color: 305, vértice 796
# Color: 270, vértice 803
# Color: 295, vértice 804
# Color: 306, vértice 836
# Color: 57, vértice 300
# Color: 306, vértice 616
# Color: 307, vértice 681
# Color: 207, vértice 867
# Color: 305, vértice 935
# Color: 308, vértice 440
# Color: 309, vértice 75
# Color: 292, vértice 213
# Color: 297, vértice 316
# Color: 290, vértice 350
# Color: 294, vértice 425
# Color: 301, vértice 471
# Color: 310, vértice 623
# Color: 301, vértice 319
# Color: 311, vértice 406
# Color: 304, vértice 829
# Color: 265, vértice 919
# Color: 310, vértice 62
# Color: 226, vértice 168
# Color: 278, vértice 590
# Color: 312, vértice 528
# Color: 309, vértice 128
# Color: 307, vértice 524
# Color: 266, vértice 575
# Color: 283, vértice 33
# Color: 83, vértice 127
# Color: 251, vértice 658
# Color: 56, vértice 442
# Color: 313, vértice 871
# Color: 308, vértice 14
# Color: 180, vértice 609
# Color: 307, vértice 727
# CPU times: total: 2.36 s
# Wall time: 2.36 s

# %% [markdown]
# ## Recocido Simulado
#
# Las implementaciones aquí son un poco más similares entre sí, no obstante el problema a resolver define fuertemente el funcionamiento puntual de cada implementación. Sigo sin poder encontrar una forma general de representar los CSP.

# %% [markdown]
# ### N Reinas

# %%
import random
import math
import time

def ataque_reinas(tab):
    """
    Una forma alterna de verificar la validez de los lugares a analizar.
    """
    n = len(tab)
    n_ataques = 0
    for i in range(n):
        for j in range(i + 1, n):
            if tab[i] == tab[j] or abs(tab[i] - tab[j]) == j - i:
                n_ataques += 1
    return n_ataques

def REC_SIM(reinas, Ti, FE):
    """
    Implementación del Recocido Simulado.
    Los parámetros definidos por Ti, FE están definidos por parte del usuario.
    """
    new_tab = [random.randint(0, reinas - 1) for _ in range(reinas)]
    new_n_ataques = ataque_reinas(new_tab)
    final_tab = list(new_tab)
    final_n_ataques = new_n_ataques

    T = Ti
    while T > 0:
        """
        Iteración bajo restricción probabilística.
        """
        m = random.randint(0, reinas - 1)
        n = random.randint(0, reinas - 1)
        next_tab = list(new_tab)
        next_tab[m] = n
        next_n_ataques = ataque_reinas(next_tab)

        delta_n_ataques = next_n_ataques - new_n_ataques
        if delta_n_ataques < 0 or random.random() < math.exp(-delta_n_ataques / T):
            new_tab = list(next_tab)
            new_n_ataques = next_n_ataques

        if new_n_ataques < final_n_ataques:
            final_tab = list(new_tab)
            final_n_ataques = new_n_ataques

        T *= FE # Reajuste

    return final_tab, final_n_ataques

def recocido_n_reinas(n, ti, fe):
    """
    Implementación completa e impresión de resultados.
    """
    sol, ataques = REC_SIM(n, ti, fe)
    if ataques == 0:
        print("Se encontró la siguiente solución:")
        for i in range(n):
            fila = ['-'] * n
            fila[sol[i]] = 'R'
            print(', '.join(fila))
    else:
        print("No se encontró solución")
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time

# Dependeindo del valor de probabilidad dado puede tomar muuuuuuuuuuuuucho tiempo.
# Con 0.5 corre muy rápido pero no siempre llega a un resultado.
# Pero al cambiar el parámetro de 0.5 a un valor distinto toma demasiado, no estoy seguro qué causa eso.

recocido_n_reinas(8, 1000, 0.5)
#recocido_n_reinas(100, 1000, 0.8) # Correr bajo su propio riesgo.
# Out:
# Se encontró la siguiente solución:
# -, -, R, -, -, -, -, -
# -, -, -, -, -, R, -, -
# -, -, -, -, -, -, -, R
# R, -, -, -, -, -, -, -
# -, -, -, R, -, -, -, -
# -, -, -, -, -, -, R, -
# -, -, -, -, R, -, -, -
# -, R, -, -, -, -, -, -
# CPU times: total: 15.6 ms
# Wall time: 9 ms

# %% [markdown]
# ### Coloreado de Grafos

# %%
import networkx as nx
import random
import math
import time

# Función leer grafo de archivo txt
# Son diferentes para el caso de backtracking. No obstante son casi iguales
def txt_grafos_recocido(name_txt):
    with open(name_txt, 'r') as archivo:
        lines = archivo.readlines()
        return lines

def crear_graph(lines):
    """
    Nuevamente vamos a crear una gráfica para facilitar el recorrido
    """
    graph = nx.Graph()
    n_vertex = 0
    for i, line in enumerate(lines):
        if i == 0:
            n_vertex, n_edge = map(int, line.split())
        else:
            a, b = map(int, line.split())
            graph.add_edge(a, b)
    return graph, n_vertex

def fun_val_coloreado(graph, coloreado):
    """
    Se cuenta la cantidad de vértices que comparten color.
    """
    val = 0
    for a, b in graph.edges():
        if coloreado[a] == coloreado[b]:
            val += 1
    return val // 2

def new_T(Ti, cont, total_cont):
    """
    Reajuste del recocido en función del estado de la gráfica.
    """
    return Ti * (1 - cont / total_cont)

def random_next(graph, coloreado, n_vertex):
    """
    Elección aleatoria de un nuevo nodo y color.
    """
    nodo = random.choice(list(graph.nodes()))
    color = random.randint(1, n_vertex)
    coloreado[nodo] = color

def REC_SIM(graph, Ti, total_cont, n_vertex):
    """
    Implementación del algoritmo de recocido simulado.
    """
    final_graph_coloreado = {nodo: 0 for nodo in graph.nodes()}
    final_valor = fun_val_coloreado(graph, final_graph_coloreado)
    final_sol = final_graph_coloreado.copy()

    Ti = Ti
    total_cont = total_cont

    new_coloreado = final_graph_coloreado.copy()
    new_val = final_valor

    # Iteración y reajuste.
    
    for cont in range(total_cont):
        T = new_T(Ti, cont, total_cont)

        nodo = random.choice(list(graph.nodes()))
        color = random.randint(1, n_vertex)
        new_coloreado[nodo] = color
        next_val = fun_val_coloreado(graph, new_coloreado)

        res_val = next_val - new_val

        if res_val < 0 or random.random() < math.exp(-res_val / T):
            new_val = next_val
            if new_val < final_valor:
                final_valor = new_val
                final_sol = new_coloreado.copy()
                final_graph_coloreado = new_coloreado.copy()
        else:
            new_coloreado = final_graph_coloreado.copy()

    return final_graph_coloreado, final_valor

def solve(archivo_txt, Ti, total_cont):
    """
    Ejecución en conjunto de todo lo desarrollado.
    """
    lines = txt_grafos_recocido(archivo_txt)
    graph, n_vertex = crear_graph(lines)
    final_graph_coloreado, final_valor = REC_SIM(graph, Ti, total_cont, n_vertex)
    colores_utilizados = len(set(final_graph_coloreado.values()))
    print("Se encontró la siguiente solución:")
    print("Número de colores:", colores_utilizados)
    for nodo, color in final_graph_coloreado.items():
        print(f"Color: {color}, vértice {nodo}")
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%time
solve(nodos50, Ti=1000, total_cont=1000)
solve(nodos1000, Ti=1000, total_cont=1000) # No tarda demasiado, un min y cachito.
# Out:
# Se encontró la siguiente solución:
# Número de colores: 494
# Color: 41, vértice 0
# Color: 535, vértice 1
# Color: 0, vértice 2
# Color: 711, vértice 3
# Color: 0, vértice 5
# Color: 0, vértice 6
# Color: 655, vértice 7
# Color: 0, vértice 8
# Color: 0, vértice 9
# Color: 646, vértice 10
# Color: 853, vértice 11
# Color: 420, vértice 12
# Color: 171, vértice 13
# Color: 141, vértice 14
# Color: 362, vértice 15
# Color: 601, vértice 16
# Color: 0, vértice 17
# Color: 0, vértice 18
# Color: 796, vértice 19
# Color: 0, vértice 21
# Color: 684, vértice 22
# Color: 0, vértice 23
# Color: 0, vértice 24
# Color: 795, vértice 25
# Color: 0, vértice 26
# Color: 0, vértice 27
# Color: 614, vértice 28
# Color: 0, vértice 29
# Color: 0, vértice 30
# Color: 0, vértice 31
# Color: 887, vértice 32
# Color: 0, vértice 33
# Color: 637, vértice 34
# Color: 374, vértice 35
# Color: 915, vértice 36
# Color: 0, vértice 37
# Color: 348, vértice 38
# Color: 0, vértice 39
# Color: 63, vértice 41
# Color: 255, vértice 42
# Color: 362, vértice 43
# Color: 0, vértice 44
# Color: 0, vértice 45
# Color: 533, vértice 46
# Color: 469, vértice 47
# Color: 0, vértice 50
# Color: 842, vértice 51
# Color: 298, vértice 52
# Color: 327, vértice 53
# Color: 947, vértice 55
# Color: 186, vértice 56
# Color: 0, vértice 57
# Color: 33, vértice 58
# Color: 68, vértice 59
# Color: 0, vértice 60
# Color: 0, vértice 61
# Color: 0, vértice 62
# Color: 58, vértice 63
# Color: 0, vértice 64
# Color: 0, vértice 65
# Color: 416, vértice 66
# Color: 111, vértice 67
# Color: 0, vértice 68
# Color: 0, vértice 69
# Color: 129, vértice 71
# Color: 918, vértice 72
# Color: 772, vértice 73
# Color: 58, vértice 74
# Color: 300, vértice 75
# Color: 955, vértice 76
# Color: 0, vértice 77
# Color: 58, vértice 79
# Color: 0, vértice 80
# Color: 0, vértice 81
# Color: 0, vértice 83
# Color: 554, vértice 84
# Color: 0, vértice 85
# Color: 640, vértice 86
# Color: 460, vértice 87
# Color: 779, vértice 88
# Color: 446, vértice 89
# Color: 385, vértice 90
# Color: 66, vértice 91
# Color: 0, vértice 92
# Color: 508, vértice 93
# Color: 0, vértice 94
# Color: 0, vértice 95
# Color: 533, vértice 96
# Color: 25, vértice 97
# Color: 0, vértice 98
# Color: 0, vértice 100
# Color: 0, vértice 101
# Color: 732, vértice 102
# Color: 311, vértice 103
# Color: 0, vértice 104
# Color: 128, vértice 105
# Color: 789, vértice 106
# Color: 792, vértice 107
# Color: 0, vértice 108
# Color: 101, vértice 109
# Color: 817, vértice 110
# Color: 0, vértice 111
# Color: 0, vértice 112
# Color: 0, vértice 113
# Color: 179, vértice 114
# Color: 0, vértice 116
# Color: 0, vértice 117
# Color: 722, vértice 118
# Color: 274, vértice 119
# Color: 585, vértice 120
# Color: 33, vértice 121
# Color: 0, vértice 122
# Color: 49, vértice 123
# Color: 42, vértice 124
# Color: 895, vértice 125
# Color: 238, vértice 126
# Color: 0, vértice 127
# Color: 189, vértice 128
# Color: 0, vértice 129
# Color: 890, vértice 130
# Color: 166, vértice 131
# Color: 62, vértice 132
# Color: 358, vértice 133
# Color: 0, vértice 134
# Color: 0, vértice 135
# Color: 864, vértice 136
# Color: 515, vértice 137
# Color: 903, vértice 138
# Color: 203, vértice 140
# Color: 440, vértice 141
# Color: 932, vértice 143
# Color: 38, vértice 144
# Color: 94, vértice 145
# Color: 299, vértice 146
# Color: 552, vértice 147
# Color: 362, vértice 148
# Color: 735, vértice 149
# Color: 784, vértice 150
# Color: 389, vértice 151
# Color: 544, vértice 152
# Color: 542, vértice 153
# Color: 838, vértice 154
# Color: 142, vértice 155
# Color: 85, vértice 156
# Color: 537, vértice 157
# Color: 555, vértice 158
# Color: 338, vértice 159
# Color: 678, vértice 160
# Color: 863, vértice 161
# Color: 0, vértice 162
# Color: 738, vértice 163
# Color: 0, vértice 164
# Color: 363, vértice 165
# Color: 44, vértice 166
# Color: 528, vértice 167
# Color: 716, vértice 168
# Color: 327, vértice 169
# Color: 483, vértice 170
# Color: 0, vértice 171
# Color: 938, vértice 172
# Color: 193, vértice 173
# Color: 311, vértice 174
# Color: 0, vértice 176
# Color: 296, vértice 177
# Color: 0, vértice 178
# Color: 113, vértice 179
# Color: 645, vértice 180
# Color: 0, vértice 181
# Color: 546, vértice 182
# Color: 500, vértice 183
# Color: 0, vértice 184
# Color: 0, vértice 185
# Color: 0, vértice 186
# Color: 0, vértice 188
# Color: 827, vértice 189
# Color: 600, vértice 190
# Color: 123, vértice 191
# Color: 725, vértice 192
# Color: 808, vértice 194
# Color: 80, vértice 195
# Color: 0, vértice 196
# Color: 896, vértice 197
# Color: 0, vértice 198
# Color: 808, vértice 199
# Color: 976, vértice 200
# Color: 35, vértice 201
# Color: 0, vértice 202
# Color: 984, vértice 203
# Color: 542, vértice 204
# Color: 261, vértice 205
# Color: 0, vértice 206
# Color: 170, vértice 207
# Color: 0, vértice 208
# Color: 42, vértice 209
# Color: 0, vértice 210
# Color: 753, vértice 211
# Color: 136, vértice 213
# Color: 860, vértice 214
# Color: 0, vértice 215
# Color: 144, vértice 216
# Color: 403, vértice 217
# Color: 793, vértice 218
# Color: 16, vértice 219
# Color: 0, vértice 220
# Color: 0, vértice 221
# Color: 0, vértice 222
# Color: 957, vértice 223
# Color: 0, vértice 224
# Color: 339, vértice 225
# Color: 492, vértice 226
# Color: 388, vértice 227
# Color: 0, vértice 228
# Color: 611, vértice 229
# Color: 0, vértice 230
# Color: 839, vértice 231
# Color: 134, vértice 232
# Color: 0, vértice 233
# Color: 0, vértice 234
# Color: 461, vértice 235
# Color: 0, vértice 236
# Color: 0, vértice 237
# Color: 0, vértice 238
# Color: 643, vértice 239
# Color: 754, vértice 240
# Color: 204, vértice 241
# Color: 331, vértice 242
# Color: 0, vértice 243
# Color: 599, vértice 244
# Color: 0, vértice 245
# Color: 0, vértice 246
# Color: 653, vértice 247
# Color: 660, vértice 249
# Color: 876, vértice 250
# Color: 464, vértice 251
# Color: 213, vértice 252
# Color: 353, vértice 253
# Color: 0, vértice 254
# Color: 982, vértice 255
# Color: 246, vértice 256
# Color: 0, vértice 257
# Color: 826, vértice 258
# Color: 0, vértice 259
# Color: 119, vértice 260
# Color: 0, vértice 261
# Color: 568, vértice 262
# Color: 48, vértice 263
# Color: 440, vértice 264
# Color: 650, vértice 265
# Color: 347, vértice 267
# Color: 437, vértice 268
# Color: 0, vértice 269
# Color: 945, vértice 270
# Color: 91, vértice 271
# Color: 298, vértice 272
# Color: 0, vértice 273
# Color: 0, vértice 274
# Color: 526, vértice 275
# Color: 692, vértice 276
# Color: 110, vértice 278
# Color: 423, vértice 279
# Color: 310, vértice 280
# Color: 817, vértice 281
# Color: 0, vértice 282
# Color: 0, vértice 283
# Color: 455, vértice 284
# Color: 0, vértice 285
# Color: 214, vértice 286
# Color: 0, vértice 288
# Color: 592, vértice 291
# Color: 0, vértice 292
# Color: 487, vértice 293
# Color: 127, vértice 294
# Color: 0, vértice 295
# Color: 0, vértice 296
# Color: 0, vértice 297
# Color: 400, vértice 298
# Color: 337, vértice 299
# Color: 288, vértice 300
# Color: 756, vértice 301
# Color: 181, vértice 302
# Color: 338, vértice 303
# Color: 0, vértice 304
# Color: 0, vértice 305
# Color: 313, vértice 306
# Color: 385, vértice 307
# Color: 905, vértice 308
# Color: 221, vértice 309
# Color: 287, vértice 310
# Color: 856, vértice 311
# Color: 296, vértice 312
# Color: 116, vértice 313
# Color: 363, vértice 314
# Color: 675, vértice 316
# Color: 0, vértice 317
# Color: 0, vértice 318
# Color: 124, vértice 319
# Color: 0, vértice 320
# Color: 380, vértice 321
# Color: 0, vértice 322
# Color: 510, vértice 323
# Color: 578, vértice 324
# Color: 0, vértice 325
# Color: 0, vértice 326
# Color: 926, vértice 327
# Color: 538, vértice 328
# Color: 336, vértice 329
# Color: 411, vértice 330
# Color: 893, vértice 331
# Color: 40, vértice 332
# Color: 739, vértice 333
# Color: 689, vértice 334
# Color: 0, vértice 335
# Color: 471, vértice 336
# Color: 951, vértice 337
# Color: 621, vértice 339
# Color: 324, vértice 340
# Color: 174, vértice 341
# Color: 58, vértice 342
# Color: 478, vértice 343
# Color: 6, vértice 344
# Color: 0, vértice 345
# Color: 0, vértice 346
# Color: 0, vértice 347
# Color: 809, vértice 348
# Color: 626, vértice 349
# Color: 148, vértice 350
# Color: 0, vértice 351
# Color: 435, vértice 352
# Color: 0, vértice 353
# Color: 407, vértice 354
# Color: 0, vértice 355
# Color: 0, vértice 356
# Color: 0, vértice 357
# Color: 948, vértice 358
# Color: 0, vértice 359
# Color: 836, vértice 360
# Color: 705, vértice 361
# Color: 843, vértice 362
# Color: 932, vértice 363
# Color: 0, vértice 364
# Color: 0, vértice 365
# Color: 0, vértice 366
# Color: 0, vértice 368
# Color: 773, vértice 369
# Color: 995, vértice 370
# Color: 841, vértice 371
# Color: 987, vértice 372
# Color: 1000, vértice 373
# Color: 0, vértice 374
# Color: 0, vértice 375
# Color: 0, vértice 376
# Color: 342, vértice 377
# Color: 830, vértice 378
# Color: 0, vértice 379
# Color: 992, vértice 380
# Color: 0, vértice 381
# Color: 125, vértice 382
# Color: 0, vértice 383
# Color: 115, vértice 384
# Color: 715, vértice 385
# Color: 82, vértice 386
# Color: 721, vértice 387
# Color: 0, vértice 388
# Color: 390, vértice 389
# Color: 827, vértice 390
# Color: 0, vértice 392
# Color: 926, vértice 393
# Color: 0, vértice 394
# Color: 769, vértice 395
# Color: 667, vértice 396
# Color: 0, vértice 397
# Color: 0, vértice 398
# Color: 0, vértice 399
# Color: 714, vértice 400
# Color: 201, vértice 401
# Color: 344, vértice 402
# Color: 432, vértice 403
# Color: 0, vértice 404
# Color: 703, vértice 405
# Color: 0, vértice 406
# Color: 201, vértice 407
# Color: 303, vértice 409
# Color: 665, vértice 411
# Color: 656, vértice 412
# Color: 276, vértice 413
# Color: 150, vértice 414
# Color: 741, vértice 415
# Color: 192, vértice 416
# Color: 781, vértice 417
# Color: 522, vértice 418
# Color: 312, vértice 419
# Color: 560, vértice 420
# Color: 28, vértice 421
# Color: 398, vértice 423
# Color: 0, vértice 425
# Color: 877, vértice 428
# Color: 321, vértice 429
# Color: 0, vértice 430
# Color: 70, vértice 432
# Color: 495, vértice 433
# Color: 454, vértice 434
# Color: 315, vértice 435
# Color: 0, vértice 437
# Color: 0, vértice 438
# Color: 311, vértice 439
# Color: 0, vértice 441
# Color: 510, vértice 443
# Color: 0, vértice 444
# Color: 0, vértice 445
# Color: 0, vértice 446
# Color: 434, vértice 447
# Color: 0, vértice 448
# Color: 0, vértice 449
# Color: 139, vértice 450
# Color: 0, vértice 451
# Color: 504, vértice 452
# Color: 817, vértice 453
# Color: 212, vértice 454
# Color: 795, vértice 455
# Color: 728, vértice 456
# Color: 938, vértice 457
# Color: 0, vértice 458
# Color: 0, vértice 460
# Color: 0, vértice 461
# Color: 0, vértice 462
# Color: 117, vértice 463
# Color: 954, vértice 464
# Color: 0, vértice 465
# Color: 0, vértice 466
# Color: 229, vértice 467
# Color: 964, vértice 468
# Color: 0, vértice 469
# Color: 443, vértice 470
# Color: 294, vértice 471
# Color: 762, vértice 472
# Color: 0, vértice 473
# Color: 869, vértice 474
# Color: 773, vértice 475
# Color: 701, vértice 476
# Color: 0, vértice 477
# Color: 0, vértice 478
# Color: 0, vértice 479
# Color: 206, vértice 480
# Color: 591, vértice 481
# Color: 471, vértice 482
# Color: 618, vértice 483
# Color: 0, vértice 484
# Color: 358, vértice 485
# Color: 475, vértice 486
# Color: 0, vértice 487
# Color: 0, vértice 488
# Color: 0, vértice 489
# Color: 826, vértice 491
# Color: 660, vértice 492
# Color: 417, vértice 493
# Color: 947, vértice 494
# Color: 886, vértice 495
# Color: 0, vértice 496
# Color: 0, vértice 497
# Color: 558, vértice 498
# Color: 0, vértice 499
# Color: 841, vértice 501
# Color: 286, vértice 502
# Color: 0, vértice 503
# Color: 971, vértice 504
# Color: 982, vértice 506
# Color: 0, vértice 507
# Color: 953, vértice 508
# Color: 6, vértice 509
# Color: 0, vértice 510
# Color: 0, vértice 511
# Color: 0, vértice 512
# Color: 615, vértice 513
# Color: 258, vértice 514
# Color: 808, vértice 515
# Color: 556, vértice 516
# Color: 0, vértice 517
# Color: 0, vértice 518
# Color: 0, vértice 519
# Color: 633, vértice 520
# Color: 303, vértice 521
# Color: 685, vértice 522
# Color: 47, vértice 523
# Color: 0, vértice 524
# Color: 14, vértice 525
# Color: 0, vértice 526
# Color: 0, vértice 527
# Color: 628, vértice 529
# Color: 739, vértice 530
# Color: 0, vértice 531
# Color: 0, vértice 533
# Color: 220, vértice 534
# Color: 247, vértice 535
# Color: 195, vértice 536
# Color: 760, vértice 537
# Color: 143, vértice 538
# Color: 932, vértice 540
# Color: 885, vértice 541
# Color: 0, vértice 542
# Color: 918, vértice 543
# Color: 0, vértice 544
# Color: 108, vértice 545
# Color: 961, vértice 546
# Color: 958, vértice 547
# Color: 936, vértice 548
# Color: 740, vértice 549
# Color: 0, vértice 550
# Color: 391, vértice 551
# Color: 0, vértice 552
# Color: 528, vértice 553
# Color: 493, vértice 554
# Color: 86, vértice 555
# Color: 393, vértice 556
# Color: 0, vértice 558
# Color: 895, vértice 559
# Color: 982, vértice 560
# Color: 91, vértice 561
# Color: 0, vértice 562
# Color: 382, vértice 563
# Color: 673, vértice 564
# Color: 226, vértice 566
# Color: 465, vértice 568
# Color: 786, vértice 569
# Color: 0, vértice 570
# Color: 163, vértice 571
# Color: 265, vértice 572
# Color: 874, vértice 574
# Color: 0, vértice 575
# Color: 0, vértice 576
# Color: 651, vértice 577
# Color: 0, vértice 578
# Color: 0, vértice 579
# Color: 354, vértice 580
# Color: 473, vértice 581
# Color: 992, vértice 582
# Color: 0, vértice 583
# Color: 0, vértice 584
# Color: 0, vértice 585
# Color: 0, vértice 586
# Color: 929, vértice 587
# Color: 591, vértice 588
# Color: 0, vértice 589
# Color: 841, vértice 590
# Color: 0, vértice 591
# Color: 637, vértice 592
# Color: 0, vértice 594
# Color: 29, vértice 595
# Color: 0, vértice 596
# Color: 691, vértice 597
# Color: 0, vértice 598
# Color: 530, vértice 599
# Color: 0, vértice 601
# Color: 715, vértice 602
# Color: 571, vértice 603
# Color: 0, vértice 604
# Color: 0, vértice 605
# Color: 276, vértice 606
# Color: 778, vértice 607
# Color: 124, vértice 608
# Color: 28, vértice 609
# Color: 0, vértice 610
# Color: 970, vértice 611
# Color: 166, vértice 612
# Color: 542, vértice 613
# Color: 191, vértice 614
# Color: 0, vértice 615
# Color: 739, vértice 616
# Color: 200, vértice 617
# Color: 480, vértice 618
# Color: 0, vértice 619
# Color: 528, vértice 620
# Color: 584, vértice 622
# Color: 13, vértice 623
# Color: 735, vértice 625
# Color: 388, vértice 628
# Color: 761, vértice 629
# Color: 0, vértice 630
# Color: 0, vértice 631
# Color: 155, vértice 632
# Color: 66, vértice 633
# Color: 0, vértice 634
# Color: 72, vértice 637
# Color: 396, vértice 639
# Color: 480, vértice 640
# Color: 882, vértice 641
# Color: 0, vértice 642
# Color: 0, vértice 643
# Color: 793, vértice 644
# Color: 463, vértice 645
# Color: 583, vértice 646
# Color: 478, vértice 647
# Color: 519, vértice 648
# Color: 387, vértice 650
# Color: 30, vértice 651
# Color: 0, vértice 652
# Color: 115, vértice 653
# Color: 625, vértice 654
# Color: 803, vértice 656
# Color: 313, vértice 657
# Color: 981, vértice 658
# Color: 512, vértice 659
# Color: 196, vértice 660
# Color: 87, vértice 661
# Color: 655, vértice 663
# Color: 484, vértice 664
# Color: 418, vértice 665
# Color: 925, vértice 666
# Color: 0, vértice 667
# Color: 675, vértice 668
# Color: 260, vértice 669
# Color: 0, vértice 670
# Color: 0, vértice 671
# Color: 687, vértice 672
# Color: 0, vértice 673
# Color: 0, vértice 674
# Color: 494, vértice 675
# Color: 345, vértice 676
# Color: 0, vértice 677
# Color: 0, vértice 678
# Color: 491, vértice 679
# Color: 725, vértice 680
# Color: 27, vértice 681
# Color: 0, vértice 682
# Color: 0, vértice 683
# Color: 138, vértice 684
# Color: 923, vértice 685
# Color: 884, vértice 686
# Color: 0, vértice 687
# Color: 211, vértice 688
# Color: 619, vértice 689
# Color: 0, vértice 690
# Color: 0, vértice 691
# Color: 0, vértice 692
# Color: 0, vértice 694
# Color: 712, vértice 695
# Color: 581, vértice 696
# Color: 989, vértice 697
# Color: 0, vértice 698
# Color: 349, vértice 699
# Color: 969, vértice 700
# Color: 457, vértice 701
# Color: 714, vértice 703
# Color: 868, vértice 704
# Color: 323, vértice 706
# Color: 0, vértice 707
# Color: 955, vértice 708
# Color: 0, vértice 709
# Color: 668, vértice 710
# Color: 41, vértice 711
# Color: 473, vértice 712
# Color: 214, vértice 713
# Color: 111, vértice 714
# Color: 906, vértice 715
# Color: 0, vértice 717
# Color: 0, vértice 718
# Color: 205, vértice 719
# Color: 0, vértice 720
# Color: 61, vértice 721
# Color: 0, vértice 722
# Color: 934, vértice 723
# Color: 629, vértice 724
# Color: 454, vértice 725
# Color: 0, vértice 726
# Color: 374, vértice 727
# Color: 306, vértice 728
# Color: 0, vértice 729
# Color: 0, vértice 730
# Color: 850, vértice 731
# Color: 934, vértice 732
# Color: 441, vértice 733
# Color: 0, vértice 735
# Color: 0, vértice 736
# Color: 794, vértice 737
# Color: 72, vértice 738
# Color: 431, vértice 739
# Color: 0, vértice 740
# Color: 0, vértice 742
# Color: 0, vértice 744
# Color: 0, vértice 747
# Color: 0, vértice 748
# Color: 989, vértice 749
# Color: 483, vértice 750
# Color: 591, vértice 751
# Color: 0, vértice 752
# Color: 0, vértice 753
# Color: 140, vértice 754
# Color: 0, vértice 755
# Color: 0, vértice 756
# Color: 579, vértice 757
# Color: 958, vértice 758
# Color: 216, vértice 759
# Color: 634, vértice 761
# Color: 58, vértice 762
# Color: 207, vértice 763
# Color: 0, vértice 764
# Color: 359, vértice 765
# Color: 61, vértice 766
# Color: 746, vértice 767
# Color: 0, vértice 768
# Color: 515, vértice 769
# Color: 858, vértice 770
# Color: 144, vértice 771
# Color: 0, vértice 772
# Color: 0, vértice 773
# Color: 23, vértice 774
# Color: 836, vértice 775
# Color: 315, vértice 776
# Color: 0, vértice 777
# Color: 832, vértice 778
# Color: 0, vértice 779
# Color: 107, vértice 780
# Color: 0, vértice 781
# Color: 460, vértice 782
# Color: 736, vértice 783
# Color: 628, vértice 784
# Color: 926, vértice 786
# Color: 307, vértice 787
# Color: 911, vértice 788
# Color: 62, vértice 789
# Color: 253, vértice 790
# Color: 184, vértice 791
# Color: 134, vértice 793
# Color: 550, vértice 794
# Color: 0, vértice 795
# Color: 0, vértice 796
# Color: 779, vértice 797
# Color: 0, vértice 798
# Color: 455, vértice 799
# Color: 0, vértice 800
# Color: 224, vértice 801
# Color: 0, vértice 802
# Color: 528, vértice 803
# Color: 398, vértice 804
# Color: 0, vértice 805
# Color: 107, vértice 807
# Color: 330, vértice 808
# Color: 0, vértice 809
# Color: 886, vértice 810
# Color: 985, vértice 811
# Color: 172, vértice 812
# Color: 763, vértice 813
# Color: 810, vértice 814
# Color: 558, vértice 815
# Color: 300, vértice 816
# Color: 434, vértice 817
# Color: 0, vértice 818
# Color: 818, vértice 819
# Color: 0, vértice 820
# Color: 799, vértice 821
# Color: 533, vértice 822
# Color: 821, vértice 823
# Color: 572, vértice 824
# Color: 0, vértice 825
# Color: 588, vértice 827
# Color: 0, vértice 828
# Color: 20, vértice 829
# Color: 0, vértice 830
# Color: 0, vértice 831
# Color: 517, vértice 832
# Color: 163, vértice 833
# Color: 740, vértice 834
# Color: 0, vértice 835
# Color: 0, vértice 836
# Color: 921, vértice 837
# Color: 718, vértice 838
# Color: 880, vértice 839
# Color: 0, vértice 841
# Color: 0, vértice 843
# Color: 445, vértice 844
# Color: 0, vértice 845
# Color: 989, vértice 846
# Color: 529, vértice 847
# Color: 326, vértice 848
# Color: 0, vértice 850
# Color: 865, vértice 851
# Color: 0, vértice 852
# Color: 302, vértice 854
# Color: 17, vértice 855
# Color: 309, vértice 856
# Color: 490, vértice 857
# Color: 0, vértice 858
# Color: 806, vértice 859
# Color: 0, vértice 860
# Color: 397, vértice 861
# Color: 283, vértice 862
# Color: 0, vértice 863
# Color: 402, vértice 864
# Color: 0, vértice 865
# Color: 916, vértice 866
# Color: 96, vértice 867
# Color: 621, vértice 868
# Color: 369, vértice 869
# Color: 520, vértice 870
# Color: 363, vértice 871
# Color: 709, vértice 872
# Color: 0, vértice 873
# Color: 854, vértice 874
# Color: 944, vértice 875
# Color: 230, vértice 876
# Color: 0, vértice 877
# Color: 898, vértice 878
# Color: 0, vértice 879
# Color: 0, vértice 880
# Color: 0, vértice 881
# Color: 384, vértice 882
# Color: 287, vértice 883
# Color: 0, vértice 884
# Color: 535, vértice 886
# Color: 0, vértice 887
# Color: 689, vértice 888
# Color: 634, vértice 889
# Color: 0, vértice 891
# Color: 316, vértice 892
# Color: 506, vértice 893
# Color: 82, vértice 894
# Color: 0, vértice 896
# Color: 46, vértice 897
# Color: 0, vértice 898
# Color: 613, vértice 899
# Color: 0, vértice 900
# Color: 0, vértice 901
# Color: 0, vértice 902
# Color: 0, vértice 903
# Color: 608, vértice 904
# Color: 625, vértice 905
# Color: 0, vértice 906
# Color: 703, vértice 907
# Color: 0, vértice 908
# Color: 0, vértice 909
# Color: 0, vértice 910
# Color: 0, vértice 911
# Color: 0, vértice 912
# Color: 0, vértice 913
# Color: 333, vértice 915
# Color: 0, vértice 916
# Color: 637, vértice 917
# Color: 725, vértice 918
# Color: 0, vértice 919
# Color: 0, vértice 920
# Color: 0, vértice 921
# Color: 737, vértice 922
# Color: 49, vértice 923
# Color: 0, vértice 924
# Color: 0, vértice 925
# Color: 693, vértice 926
# Color: 397, vértice 927
# Color: 0, vértice 928
# Color: 219, vértice 929
# Color: 517, vértice 930
# Color: 174, vértice 931
# Color: 855, vértice 932
# Color: 922, vértice 933
# Color: 601, vértice 934
# Color: 361, vértice 935
# Color: 0, vértice 936
# Color: 0, vértice 938
# Color: 818, vértice 939
# Color: 659, vértice 940
# Color: 90, vértice 941
# Color: 345, vértice 942
# Color: 641, vértice 943
# Color: 270, vértice 944
# Color: 0, vértice 945
# Color: 118, vértice 946
# Color: 65, vértice 947
# Color: 119, vértice 948
# Color: 275, vértice 949
# Color: 0, vértice 950
# Color: 0, vértice 951
# Color: 172, vértice 952
# Color: 691, vértice 953
# Color: 704, vértice 955
# Color: 0, vértice 957
# Color: 700, vértice 958
# Color: 0, vértice 959
# Color: 939, vértice 960
# Color: 965, vértice 961
# Color: 264, vértice 962
# Color: 643, vértice 964
# Color: 216, vértice 965
# Color: 0, vértice 967
# Color: 247, vértice 968
# Color: 215, vértice 969
# Color: 0, vértice 970
# Color: 897, vértice 971
# Color: 952, vértice 972
# Color: 0, vértice 973
# Color: 904, vértice 974
# Color: 54, vértice 975
# Color: 0, vértice 976
# Color: 489, vértice 977
# Color: 490, vértice 978
# Color: 0, vértice 979
# Color: 479, vértice 981
# Color: 0, vértice 983
# Color: 380, vértice 984
# Color: 963, vértice 985
# Color: 0, vértice 986
# Color: 469, vértice 987
# Color: 98, vértice 988
# Color: 0, vértice 989
# Color: 205, vértice 990
# Color: 324, vértice 991
# Color: 747, vértice 992
# Color: 774, vértice 993
# Color: 15, vértice 994
# Color: 0, vértice 995
# Color: 663, vértice 997
# Color: 0, vértice 998
# Color: 829, vértice 999
# Color: 888, vértice 4
# Color: 0, vértice 20
# Color: 0, vértice 40
# Color: 749, vértice 48
# Color: 616, vértice 49
# Color: 632, vértice 54
# Color: 706, vértice 70
# Color: 565, vértice 78
# Color: 838, vértice 82
# Color: 0, vértice 99
# Color: 501, vértice 115
# Color: 398, vértice 139
# Color: 405, vértice 142
# Color: 544, vértice 175
# Color: 185, vértice 187
# Color: 0, vértice 193
# Color: 0, vértice 212
# Color: 181, vértice 248
# Color: 222, vértice 266
# Color: 661, vértice 287
# Color: 0, vértice 290
# Color: 180, vértice 315
# Color: 549, vértice 338
# Color: 0, vértice 367
# Color: 0, vértice 391
# Color: 0, vértice 408
# Color: 213, vértice 410
# Color: 426, vértice 422
# Color: 224, vértice 424
# Color: 0, vértice 426
# Color: 851, vértice 427
# Color: 851, vértice 431
# Color: 872, vértice 436
# Color: 0, vértice 440
# Color: 993, vértice 442
# Color: 0, vértice 459
# Color: 0, vértice 490
# Color: 409, vértice 500
# Color: 867, vértice 505
# Color: 0, vértice 528
# Color: 0, vértice 539
# Color: 910, vértice 565
# Color: 237, vértice 567
# Color: 74, vértice 573
# Color: 20, vértice 593
# Color: 107, vértice 600
# Color: 0, vértice 621
# Color: 284, vértice 624
# Color: 279, vértice 626
# Color: 47, vértice 627
# Color: 883, vértice 635
# Color: 577, vértice 636
# Color: 189, vértice 638
# Color: 0, vértice 649
# Color: 0, vértice 655
# Color: 69, vértice 662
# Color: 636, vértice 693
# Color: 0, vértice 702
# Color: 0, vértice 741
# Color: 311, vértice 743
# Color: 795, vértice 745
# Color: 941, vértice 746
# Color: 107, vértice 760
# Color: 0, vértice 792
# Color: 0, vértice 806
# Color: 143, vértice 826
# Color: 0, vértice 842
# Color: 517, vértice 849
# Color: 486, vértice 853
# Color: 0, vértice 885
# Color: 0, vértice 890
# Color: 851, vértice 895
# Color: 0, vértice 914
# Color: 959, vértice 937
# Color: 407, vértice 954
# Color: 659, vértice 956
# Color: 912, vértice 963
# Color: 51, vértice 966
# Color: 0, vértice 980
# Color: 789, vértice 982
# Color: 770, vértice 996
# Color: 650, vértice 289
# Color: 731, vértice 532
# Color: 451, vértice 557
# Color: 0, vértice 705
# Color: 33, vértice 716
# Color: 724, vértice 734
# Color: 0, vértice 785
# Color: 403, vértice 840
# Color: 79, vértice 277
# CPU times: total: 1min 3s
# Wall time: 1min 4s

# %% [markdown]
# ## Minimax
#
# Como tal no se implementó Minimax, el uso del repo es inconsistente y hay propiedades privadas de los elementos del entorno

# %%
#!git clone https://github.com/LudwigStumpp/gym-tic-tac-toe.git
# Out:
# Cloning into 'gym-tic-tac-toe'...

# %%
# %cd gym-tic-tac-toe
# Out:
# C:\Users\FLopezP\Desktop\PCIC\IA\gym-tic-tac-toe
# C:\Users\FLopezP\Anaconda3\envs\Prueba1\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import gym

env = gym.make('gym_tictactoe:tictactoe-v0')
env.reset()
env.render()

# El tablero está etiquetado de la siguiente manera:
# |0|1|2|
# |3|4|5|
# |6|7|8|
# Out:
# | | | |
# | | | |
# | | | |
# C:\Users\FLopezP\Anaconda3\envs\Prueba1\lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# C:\Users\FLopezP\Anaconda3\envs\Prueba1\lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# C:\Users\FLopezP\Anaconda3\envs\Prueba1\lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'int'>`
#   logger.warn(
# C:\Users\FLopezP\Anaconda3\envs\Prueba1\lib\site-packages\gym\utils\passive_env_checker.py:272: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(

# %%
env.reset()
w, x, y, z = env.step(([0, 3]))
print(z)
env.render()
# Out:
# normal move player 1
# | | | |
# |O| | |
# | | | |

# %%
env.reset()
for a in env.get_valid_moves():
    env.step((1,a))
    env.render()
    env.reset()
    print("---------------")
# Out:
# |X| | |
# | | | |
# | | | |
# ---------------
# | |X| |
# | | | |
# | | | |
# ---------------
# | | |X|
# | | | |
# | | | |
# ---------------
# | | | |
# |X| | |
# | | | |
# ---------------
# | | | |
# | |X| |
# | | | |
# ---------------
# | | | |
# | | |X|
# | | | |
# ---------------
# | | | |
# | | | |
# |X| | |
# ---------------
# | | | |
# | | | |
# | |X| |
# ---------------
# | | | |
# | | | |
# | | |X|
# ---------------

# %%
env1 = gym.make('gym_tictactoe:tictactoe-v0')
env1.reset()
#env1.render()
# Out:
# 0

# %%
env1.reset()

for i in range(9):
    jug = i%2
    a, b, c, d = env1.step((jug, i)) # No entiendo, a veces funciona bien a veces no.
    print(d)
    
    env1.render()
    if c:
        print(f"Ganó jugador {jug+1}")
        break
    #if env1._is_full():
        #print("NO HAY ESPACIO") # Esta cosa molesta demasiado wtf
# Out:
# normal move player 1
# |O| | |
# | | | |
# | | | |
# normal move player 2
# |O|X| |
# | | | |
# | | | |
# normal move player 1
# |O|X|O|
# | | | |
# | | | |
# normal move player 2
# |O|X|O|
# |X| | |
# | | | |
# normal move player 1
# |O|X|O|
# |X|O| |
# | | | |
# normal move player 2
# |O|X|O|
# |X|O|X|
# | | | |
# winning move player 1
# |O|X|O|
# |X|O|X|
# |O| | |
# Ganó jugador 1

# %%
import random
a = random.randint(0, len(env1.get_valid_moves())-1)
print(a)
# Out:
# 1

# %%
def juego_random():
    env_aux = gym.make('gym_tictactoe:tictactoe-v0')
    env_aux.reset()
    jug_inicial = 0
    while len(env_aux.get_valid_moves()) != 0:
        jug = jug_inicial % 2
        jugada = random.randint(0, len(env1.get_valid_moves())-1)
        a, b, c, d = env_aux.step((jug, jugada))
        env_aux.render()
        print("----")
        if c:
            print(f"Ganó el jugador {jug+1}")
            break

# %%
# Este es un ejemplo de los problemas con los que me topé a la hora de ejecutar una iteración sobre el juego.
juego_random()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Este es un ejemplo de los problemas con los que me topé a la hora de ejecutar una iteración sobre el juego.
# ----> 2 juego_random()
#
# Cell In[12], line 8, in juego_random()
#       6 jug = jug_inicial % 2
#       7 jugada = random.randint(0, len(env1.get_valid_moves())-1)
# ----> 8 a, b, c, d = env_aux.step((jug, jugada))
#       9 env_aux.render()
#      10 print("----")
#
# File ~\Anaconda3\envs\Prueba1\lib\site-packages\gym\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~\Anaconda3\envs\Prueba1\lib\site-packages\gym\wrappers\env_checker.py:37, in PassiveEnvChecker.step(self, action)
#      35 if self.checked_step is False:
#      36     self.checked_step = True
# ---> 37     return env_step_passive_checker(self.env, action)
#      38 else:
#      39     return self.env.step(action)
#
# File ~\Anaconda3\envs\Prueba1\lib\site-packages\gym\utils\passive_env_checker.py:261, in env_step_passive_checker(env, action)
#     258     if np.isinf(reward):
#     259         logger.warn("The reward is an inf value.")
# --> 261 assert isinstance(
#     262     info, dict
#     263 ), f"The `info` returned by `step()` must be a python dictionary, actual type: {type(info)}"
#     265 return result
#
# AssertionError: The `info` returned by `step()` must be a python dictionary, actual type: <class 'str'>

# %%
env._is_full()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 env._is_full()
#
# File ~\Anaconda3\envs\Prueba1\lib\site-packages\gym\core.py:240, in Wrapper.__getattr__(self, name)
#     238 """Returns an attribute with ``name``, unless ``name`` starts with an underscore."""
#     239 if name.startswith("_"):
# --> 240     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
#     241 return getattr(self.env, name)
#
# AttributeError: accessing private attribute '_is_full' is prohibited
